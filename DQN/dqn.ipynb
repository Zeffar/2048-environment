# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import numpy as np
import time
import Environment_2048 
import subprocess

# %%
env = Environment_2048()
env.reset()

# %%
for step in range(15):
    # env.render() -> later 
    action = env.action_space.sample()
    observation, reward, termianted= env.step(action)
    # time.sleep(1)

    done = termianted
    if done :
        env.reset()

env.close()

# %%
action_size = env.action_space.n
state_size = env.observation_space.n

#TODO -> de vazut cum ar trebui sa arate tabelul
q_table = np.zeros([state_size, action_size])

# %%
EPISODES = 30000

# learning rate
ALPHA = 0.82

# discount rate
GAMMA = 0.9555

epsilon = 1.0
max_epsilon = 1.0
minimum_epsilon = 0.01
decay_rate = 0.001

# %%
def epsilon_greedy(epsilon, q_table, discrete_state):
    random_number = np.random.random()

    # Exploitation (choose the action the maximizes Q)
    if random_number > epsilon:
        #TODO sa facem Q-table-ul 
        # state_row = q_table[discrete_state, :]
        # action = np.argmax(state_row)
    # Exploration (choose a random action)
    else:
        action = subprocess.run(["D:/Afaculta/Anul 3 sem 1/RL/Proiect/2048-environment/decision_tree/MCTS.exe"],
                              capture_output=True, text=True).stdout.strip()

    return action
